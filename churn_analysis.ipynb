# %%
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.11.2-cp312-cp312-win_amd64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.4.0-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.65.0-cp312-cp312-win_amd64.whl.metadata (127 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.1-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (26.3)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.2-cp312-cp312-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.3 MB 4.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.3 MB 4.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.6/9.3 MB 4.3 MB/s eta 0:00:02
#    -------------- ------------------------- 3.4/9.3 MB 4.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.3 MB 4.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.2/9.3 MB 4.2 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.3 MB 4.4 MB/s eta 0:00:01
#    ------------------------------ --------- 7.1/9.3 MB 4.4 MB/s eta 0:00:01
#    -------------------------------- ------- 7.6/9.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.3 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 8.7/9.3 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 3.3 MB/s eta 0:00:00
# Downloading contourpy-1.4.0-cp312-cp312-win_amd64.whl (234 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.65.0-cp312-cp312-win_amd64.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 2.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.0/2.5 MB 3.0 MB/s eta 0:00:01
#    ------------------------- -------------- 1.6/2.5 MB 2.5 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 2.3 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.1-cp312-cp312-win_amd64.whl (70 kB)
# Downloading pillow-12.3.0-cp312-cp312-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.2 MB 1.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.8/7.2 MB 1.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.8/7.2 MB 1.5 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.0/7.2 MB 931.8 kB/s eta 0:00:07
#    ----- ---------------------------------- 1.0/7.2 MB 931.8 kB/s eta 0:00:07
#    ----- ---------------------------------- 1.0/7.2 MB 931.8 kB/s eta 0:00:07
#    ------- -------------------------------- 1.3/7.2 MB 737.4 kB/s eta 0:00:09
#    ------- -------------------------------- 1.3/7.2 MB 737.4 kB/s eta 0:00:09
#    ------- -------------------------------- 1.3/7.2 MB 737.4 kB/s eta 0:00:09
#    ------- -------------------------------- 1.3/7.2 MB 737.4 kB/s eta 0:00:09
#    ------- -------------------------------- 1.3/7.2 MB 737.4 kB/s eta 0:00:09
#    ------- -------------------------------- 1.3/7.2 MB 737.4 kB/s eta 0:00:09
#    ------- -------------------------------- 1.3/7.2 MB 737.4 kB/s eta 0:00:09
#    ------- -------------------------------- 1.3/7.2 MB 737.4 kB/s eta 0:00:09
#    ------- -------------------------------- 1.3/7.2 MB 737.4 kB/s eta 0:00:09
#    ------- -------------------------------- 1.3/7.2 MB 737.4 kB/s eta 0:00:09
#    -------- ------------------------------- 1.6/7.2 MB 371.2 kB/s eta 0:00:16
#    -------- ------------------------------- 1.6/7.2 MB 371.2 kB/s eta 0:00:16
#    -------- ------------------------------- 1.6/7.2 MB 371.2 kB/s eta 0:00:16
#    -------- ------------------------------- 1.6/7.2 MB 371.2 kB/s eta 0:00:16
#    -------- ------------------------------- 1.6/7.2 MB 371.2 kB/s eta 0:00:16
#    -------- ------------------------------- 1.6/7.2 MB 371.2 kB/s eta 0:00:16
#    -------- ------------------------------- 1.6/7.2 MB 371.2 kB/s eta 0:00:16
#    -------- ------------------------------- 1.6/7.2 MB 371.2 kB/s eta 0:00:16
#    -------- ------------------------------- 1.6/7.2 MB 371.2 kB/s eta 0:00:16
#    -------- ------------------------------- 1.6/7.2 MB 371.2 kB/s eta 0:00:16
#    -------- ------------------------------- 1.6/7.2 MB 371.2 kB/s eta 0:00:16
#    -------- ------------------------------- 1.6/7.2 MB 371.2 kB/s eta 0:00:16
#    -------- ------------------------------- 1.6/7.2 MB 371.2 kB/s eta 0:00:16
#    ---------- ----------------------------- 1.8/7.2 MB 246.1 kB/s eta 0:00:22
#    ---------- ----------------------------- 1.8/7.2 MB 246.1 kB/s eta 0:00:22
#    ---------- ----------------------------- 1.8/7.2 MB 246.1 kB/s eta 0:00:22
#    ----------- ---------------------------- 2.1/7.2 MB 258.7 kB/s eta 0:00:20
#    ----------- ---------------------------- 2.1/7.2 MB 258.7 kB/s eta 0:00:20
#    ------------- -------------------------- 2.4/7.2 MB 279.6 kB/s eta 0:00:18
#    ------------- -------------------------- 2.4/7.2 MB 279.6 kB/s eta 0:00:18
#    -------------- ------------------------- 2.6/7.2 MB 300.8 kB/s eta 0:00:16
#    --------------- ------------------------ 2.9/7.2 MB 320.8 kB/s eta 0:00:14
#    --------------- ------------------------ 2.9/7.2 MB 320.8 kB/s eta 0:00:14
#    ----------------- ---------------------- 3.1/7.2 MB 338.0 kB/s eta 0:00:13
#    ------------------ --------------------- 3.4/7.2 MB 356.3 kB/s eta 0:00:11
#    ------------------ --------------------- 3.4/7.2 MB 356.3 kB/s eta 0:00:11
#    ------------------ --------------------- 3.4/7.2 MB 356.3 kB/s eta 0:00:11
#    ------------------ --------------------- 3.4/7.2 MB 356.3 kB/s eta 0:00:11
#    -------------------- ------------------- 3.7/7.2 MB 354.7 kB/s eta 0:00:11
#    --------------------- ------------------ 3.9/7.2 MB 368.7 kB/s eta 0:00:09
#    --------------------- ------------------ 3.9/7.2 MB 368.7 kB/s eta 0:00:09
#    ----------------------- ---------------- 4.2/7.2 MB 383.0 kB/s eta 0:00:08
#    ------------------------ --------------- 4.5/7.2 MB 396.5 kB/s eta 0:00:07
#    -------------------------- ------------- 4.7/7.2 MB 412.2 kB/s eta 0:00:07
#    --------------------------- ------------ 5.0/7.2 MB 428.3 kB/s eta 0:00:06
#    --------------------------- ------------ 5.0/7.2 MB 428.3 kB/s eta 0:00:06
#    ----------------------------- ---------- 5.2/7.2 MB 440.3 kB/s eta 0:00:05
#    ------------------------------ --------- 5.5/7.2 MB 450.4 kB/s eta 0:00:04
#    ------------------------------ --------- 5.5/7.2 MB 450.4 kB/s eta 0:00:04
#    ------------------------------ --------- 5.5/7.2 MB 450.4 kB/s eta 0:00:04
#    ------------------------------ --------- 5.5/7.2 MB 450.4 kB/s eta 0:00:04
#    ------------------------------ --------- 5.5/7.2 MB 450.4 kB/s eta 0:00:04
#    ------------------------------ --------- 5.5/7.2 MB 450.4 kB/s eta 0:00:04
#    ------------------------------ --------- 5.5/7.2 MB 450.4 kB/s eta 0:00:04
#    ------------------------------- -------- 5.8/7.2 MB 417.0 kB/s eta 0:00:04
#    ------------------------------- -------- 5.8/7.2 MB 417.0 kB/s eta 0:00:04
#    ------------------------------- -------- 5.8/7.2 MB 417.0 kB/s eta 0:00:04
#    --------------------------------- ------ 6.0/7.2 MB 418.0 kB/s eta 0:00:03
#    --------------------------------- ------ 6.0/7.2 MB 418.0 kB/s eta 0:00:03
#    ---------------------------------- ----- 6.3/7.2 MB 425.0 kB/s eta 0:00:03
#    ---------------------------------- ----- 6.3/7.2 MB 425.0 kB/s eta 0:00:03
#    ------------------------------------ --- 6.6/7.2 MB 432.0 kB/s eta 0:00:02
#    ------------------------------------- -- 6.8/7.2 MB 441.5 kB/s eta 0:00:01
#    ------------------------------------- -- 6.8/7.2 MB 441.5 kB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 453.5 kB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.4.0 cycler-0.12.1 fonttools-4.65.0 kiwisolver-1.5.1 matplotlib-3.11.2 pillow-12.3.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: C:\Users\Lenovo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv(r"c:\Users\Lenovo\Downloads\European_Bank.csv", encoding='latin-1')

# %%
df.head()
# Out:
#    Year  CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0  2025    15634602  Hargrave          619    France  Female   42       2
# 1  2025    15647311      Hill          608     Spain  Female   41       1
# 2  2025    15619304      Onio          502    France  Female   42       8
# 3  2025    15701354      Boni          699    France  Female   39       1
# 4  2025    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
df.describe()
# Out:
#           Year    CustomerId   CreditScore           Age        Tenure  \
# count  10000.0  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    2025.0  1.569094e+07    650.528800     38.921800      5.012800
# std        0.0  7.193619e+04     96.653299     10.487806      2.892174
# min     2025.0  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2025.0  1.562853e+07    584.000000     32.000000      3.000000
# 50%     2025.0  1.569074e+07    652.000000     37.000000      5.000000
# 75%     2025.0  1.575323e+07    718.000000     44.000000      7.000000
# max     2025.0  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  str
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  str
#  5   Gender           10000 non-null  str
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), str(3)
# memory usage: 1.1 MB

# %%
df.columns
# Out:
# Index(['Year', 'CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender',
#        'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# Year               0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df['Geography'].value_counts())
print(df['Surname'].value_counts())
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64
# Surname
# Smith        32
# Scott        29
# Martin       29
# Walker       28
# Brown        26
#              ..
# Salinas       1
# Cleveland     1
# Kashiwagi     1
# Aldridge      1
# Burbidge      1
# Name: count, Length: 2932, dtype: int64

# %%
print(df['Exited'].value_counts())
print (df['Exited'].value_counts(normalize=True))
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64
# Exited
# 0    0.7963
# 1    0.2037
# Name: proportion, dtype: float64

# %%
df.groupby('Geography')['Exited'].mean()
# Out:
# Geography
# France     0.161548
# Germany    0.324432
# Spain      0.166734
# Name: Exited, dtype: float64

# %%
df.groupby('Gender')['Exited'].mean()
# Out:
# Gender
# Female    0.250715
# Male      0.164559
# Name: Exited, dtype: float64

# %%
df.groupby('IsActiveMember')['Exited'].mean()
# Out:
# IsActiveMember
# 0    0.268509
# 1    0.142691
# Name: Exited, dtype: float64

# %%
df.groupby('Exited')[['Age', 'Balance', 'CreditScore', 'EstimatedSalary', 'Tenure']].mean()
# Out:
#               Age       Balance  CreditScore  EstimatedSalary    Tenure
# Exited
# 0       37.408389  72745.296779   651.853196     99738.391772  5.033279
# 1       44.837997  91108.539337   645.351497    101465.677531  4.932744

# %%
df.boxplot(column='Age', by='Exited')
plt.title('Age Distribution by Churn Status')
plt.suptitle('')  # removes the default ugly subtitle
plt.xlabel('Exited (0 = Stayed, 1 = Churned)')
plt.ylabel('Age')
plt.show()
